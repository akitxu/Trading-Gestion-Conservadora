# %% [markdown]
# <div style="text-align:center; font-size:26px; color:green;">Crisis Financieras 1970 - 2024.  </div>
#
# Si no compartes el conocimiento no sirve para nada. [Michio Kaku](https://www.youtube.com/watch?v=6rDxlolYUQw)

# %% [markdown]
# # Bibliotecas Utilizadas
#
# En este proyecto, utilizamos las siguientes bibliotecas de terceros:
#
# - [yfinance](https://github.com/ranaroussi/yfinance): Una biblioteca de Python que proporciona una interfaz para acceder a los datos de Yahoo Finance.
# - [Matplotlib](https://matplotlib.org/): Una biblioteca de trazado en 2D de Python que produce figuras de calidad de publicación en una variedad de formatos impresos y entornos interactivos a través de interfaces de usuario.
# - [Plotly](https://plotly.com/python/): Una biblioteca de gráficos interactivos para Python que ofrece una variedad de opciones de visualización y personalización.
# - [Talib](https://github.com/mrjbq7/ta-lib): Una biblioteca de análisis técnico de código abierto (licencia BSD) para Python.

# %% [markdown]
# # Histórico de crisis finacieras.

# %% [markdown]
# - **Crisis del petróleo de 1973:** Después de que la OPEP aumentara drásticamente el precio del petróleo, se produjo una crisis energética global que afectó a muchas economías, especialmente a aquellas altamente dependientes del petróleo importado.
#
#  - **Crisis financiera de América Latina (década de 1980):** Varios países latinoamericanos, como México, Argentina y Brasil, experimentaron crisis de deuda soberana y problemas económicos graves, causados en parte por altos niveles de endeudamiento y políticas económicas deficientes.
#
# - **Lunes Negro (1987):** El 19 de octubre de 1987, conocido como "Lunes Negro", los mercados de valores de todo el mundo sufrieron una caída repentina y dramática. La crisis se propagó rápidamente debido a la interconexión global de los mercados financieros.
#
# - **Crisis financiera de Asia (1997-1998):** Comenzando en Tailandia con la devaluación del baht tailandés, esta crisis se propagó rápidamente a otros países del sudeste asiático, como Indonesia, Corea del Sur y Malasia. Fue desencadenada por una combinación de factores, incluidos altos niveles de endeudamiento externo, especulación financiera y debilidades en los sistemas financieros nacionales.
#
# - **Crisis del rublo ruso (1998):** Rusia enfrentó una crisis financiera y económica severa en 1998, que incluyó una devaluación significativa del rublo y un incumplimiento en el pago de la deuda soberana. Esta crisis tuvo repercusiones en los mercados financieros internacionales.
#
# - **Crisis de las punto com (2000-2002):** Esta crisis se centró en el colapso de muchas empresas de tecnología de la información en 2000. El mercado de valores experimentó una caída significativa, especialmente en las acciones de las empresas de Internet.
#
# - **Crisis financiera mundial (2007-2008):** También conocida como la Gran Recesión, esta crisis financiera global fue desencadenada por la crisis de las hipotecas de alto riesgo (subprime) en Estados Unidos. Se extendió por todo el mundo, causando una recesión económica severa y afectando los mercados financieros internacionales.
#
# - **Crisis de la deuda soberana en Europa (2010-2012):** Esta crisis se centró en la incapacidad de varios países de la Eurozona para pagar su deuda soberana, lo que generó preocupaciones sobre la solvencia de la zona euro en su conjunto. Países como Grecia, Portugal, Irlanda, España e Italia enfrentaron dificultades financieras significativas.
#
# - **Crisis financiera en China (2015-2016):** Durante este período, China experimentó una serie de desafíos financieros, incluida una desaceleración económica, una caída en el mercado de valores y una devaluación de su moneda, el yuan.
#
# - **Crisis bancaria en España (2018):** Durante la crisis bancaria en España de 2018, el S&P 500 experimentó cierta volatilidad, pero no alcanzó mínimos notables asociados específicamente con esta crisis. El impacto en el mercado global fue más limitado en comparación con otras crisis financieras.
#
# - **Crisis del COVID-19 (2020):** La pandemia de COVID-19 desencadenó una crisis económica mundial sin precedentes. Las medidas de confinamiento y distanciamiento social para contener la propagación del virus llevaron a cierres de empresas, pérdida de empleos y una recesión global.

# %% [markdown]
# # Comportamiento del S&P 500.

# %% [markdown]
# - **Crisis del petróleo de 1973:** El valor mínimo del S&P 500 durante esta crisis ocurrió en octubre de 1974, cuando alcanzó aproximadamente los 62 puntos.
#
# - **Crisis financiera de América Latina (década de 1980):** Durante esta década, el S&P 500 no experimentó un mínimo significativo asociado específicamente con la crisis financiera de América Latina. Sin embargo, hubo fluctuaciones en el mercado de valores durante este período.
#
# - **Lunes Negro (1987):** El lunes negro del 19 de octubre de 1987, el S&P 500 experimentó una caída significativa y su valor mínimo alcanzó alrededor de los 225 puntos.
#
# - **Crisis financiera de Asia (1997-1998):** Durante esta crisis, el S&P 500 experimentó volatilidad, pero no alcanzó mínimos notables asociados específicamente con la crisis financiera de Asia.
#
# - **Crisis del rublo ruso (1998):** El S&P 500 no experimentó un mínimo significativo asociado específicamente con la crisis del rublo ruso en 1998.
#
# - **Crisis de las punto com (2000-2002):** Durante la crisis de las punto com, el S&P 500 alcanzó su mínimo en octubre de 2002, cayendo a alrededor de los 777 puntos.
#
# - **Crisis financiera mundial (2007-2008):** Durante la crisis financiera mundial, el S&P 500 alcanzó su mínimo en marzo de 2009, descendiendo a aproximadamente los 666 puntos.
#
# - **Crisis de la deuda soberana en Europa (2010-2012):** Durante esta crisis, el S&P 500 no experimentó un mínimo significativo asociado específicamente con la crisis de la deuda soberana en Europa.
#
# - **Crisis financiera en China (2015-2016):** Durante esta crisis, el S&P 500 experimentó volatilidad, pero no alcanzó mínimos notables asociados específicamente con la crisis financiera en China.
#
# - **Crisis bancaria en España (2018):** Durante la crisis bancaria en España de 2018, el S&P 500 experimentó cierta volatilidad, pero no alcanzó mínimos notables asociados específicamente con esta crisis. El impacto en el mercado global fue más limitado en comparación con otras crisis financieras.
#
# - **Crisis del COVID-19 (2020):** En marzo de 2020, debido a la crisis del COVID-19, el S&P 500 alcanzó su mínimo, descendiendo a alrededor de los 2,237 puntos.

# %% [markdown]
# ## Valores mínimos del S&P 500 durante las crisis.
# Cotizaciones mínimas del S&P 500 durante las crisis.

# %%
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.offline import iplot
import plotly.graph_objects as go

plt.rcParams['figure.figsize'] = (8, 4)
plt.style.use('fivethirtyeight')


# Definir las fechas de las crisis financieras
crisis_dates = {
    'Crisis del petróleo de 1973': ('1973-01-01', '1974-01-01'),
    'Crisis financiera de América Latina (década de 1980)': ('1980-01-01', '1990-01-01'),
    'Lunes Negro (1987)': ('1987-10-01', '1987-11-01'),
    'Crisis financiera de Asia (1997-1998)': ('1997-07-01', '1998-01-01'),
    'Crisis del rublo ruso (1998)': ('1998-08-01', '1998-09-01'),
    'Crisis de las punto com (2000-2002)': ('2000-01-01', '2002-01-01'),
    'Crisis financiera mundial (2007-2008)': ('2007-01-01', '2009-01-01'),
    'Crisis de la deuda soberana en Europa (2010-2012)': ('2010-01-01', '2012-01-01'),
    'Crisis financiera en China (2015-2016)': ('2015-06-01', '2016-01-01'),
    'Crisis del COVID-19 (2020)': ('2020-01-01', '2021-01-01')
}

# Función para obtener el valor mínimo del S&P 500 dentro de un rango de fechas
def obtener_minimo_sp500(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date, progress=False)
    return data['Adj Close'].min()

# Parámetros de análisis
ticker = '^GSPC'
value_name = 'S&P 500'
start_date = '2011-1-4'
#end_date = '2024-6-28'
end_date = datetime.now()

# Iterar sobre las crisis y obtener los valores mínimos
for crisis, (start_date, end_date) in crisis_dates.items():
    min_value = obtener_minimo_sp500(ticker, start_date, end_date)
    print(f"Valor mínimo del S&P 500 durante {crisis}: {min_value:.2f}")
# Out:
# Valor mínimo del S&P 500 durante Crisis del petróleo de 1973: 92.16
# Valor mínimo del S&P 500 durante Crisis financiera de América Latina (década de 1980): 98.22
# Valor mínimo del S&P 500 durante Lunes Negro (1987): 224.84
# Valor mínimo del S&P 500 durante Crisis financiera de Asia (1997-1998): 876.99
# Valor mínimo del S&P 500 durante Crisis del rublo ruso (1998): 957.28
# Valor mínimo del S&P 500 durante Crisis de las punto com (2000-2002): 965.80
# Valor mínimo del S&P 500 durante Crisis financiera mundial (2007-2008): 752.44
# Valor mínimo del S&P 500 durante Crisis de la deuda soberana en Europa (2010-2012): 1022.58
# Valor mínimo del S&P 500 durante Crisis financiera en China (2015-2016): 1867.61
# Valor mínimo del S&P 500 durante Crisis del COVID-19 (2020): 2237.40

# %% [markdown]
# ## Media y Máximos drawdowns durante las crisis.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objs as go

class CrisisAnalyzer:
    def __init__(self, ticker, value_name, start_date):
        self.ticker = ticker
        self.start_date = start_date
        self.value_name = value_name
        
    def calcular_max_drawdown(self, start_date, end_date):
        data = yf.download(self.ticker, start=start_date, end=end_date, progress=False)
        adj_close = data['Adj Close']
        
        # Calcular el drawdown acumulado
        max_drawdown = 0
        peak_value = adj_close.iloc[0]
        for value in adj_close:
            if value > peak_value:
                peak_value = value
            drawdown = (peak_value - value) / peak_value
            if drawdown > max_drawdown:
                max_drawdown = drawdown
                
        return max_drawdown * 100
    
    def obtener_drawdown_df(self, crisis_dates):
        # Crear una lista para almacenar los resultados
        drawdowns = []
        
        # Iterar sobre las crisis y calcular los drawdowns
        results = []
        for crisis, (start_date, end_date) in crisis_dates.items():
            max_drawdown = self.calcular_max_drawdown(start_date, end_date)
            drawdowns.append(max_drawdown)
            results.append({
                'Crisis': crisis,
                'Máximo Drawdown': f"{max_drawdown:.2f}%",
                'Fecha del Máximo Drawdown': end_date
            })
        
        # Calcular el promedio de los drawdowns
        mean_drawdown = sum(drawdowns) / len(drawdowns)
        
        # Convertir la lista de resultados en un DataFrame
        drawdown_df = pd.DataFrame(results)
        
        return drawdown_df, mean_drawdown

    def graficar_evolution_plotly(self):
        sp500_data = yf.download(self.ticker, start=self.start_date, progress=False)
        # Crear un gráfico interactivo con Plotly
        fig = go.Figure()
    
        # Agregar una línea para los precios de cierre ajustados
        fig.add_trace(go.Scatter(x=sp500_data.index, y=sp500_data['Adj Close'], mode='lines', name='S&P 500'))
    
        # Configurar el diseño del gráfico
        fig.update_layout(
            title=f'Evolución de los precios del {value_name} desde 1970',
            xaxis_title='Fecha',
            yaxis_title='Precio de cierre ajustado',
            xaxis=dict(
                rangeselector=dict(
                    buttons=list([
                        dict(count=1, label="1 año", step="year", stepmode="backward"),
                        dict(count=5, label="5 años", step="year", stepmode="backward"),
                        dict(count=10, label="10 años", step="year", stepmode="backward"),
                        dict(count=20, label="20 años", step="year", stepmode="backward"),
                        dict(count=30, label="30 años", step="year", stepmode="backward"),
                        dict(step="all")
                    ])
                ),
                rangeslider=dict(visible=True),
                type="date"
            ),
            **{  # Agregar el tamaño de la ventana
                "width": 1000,  # Ajustar el ancho a 10 unidades (por defecto son 1200)
                "height": 500   # Ajustar la altura a 5 unidades (por defecto son 800)
            }
        )
    
        # Mostrar el gráfico interactivo
        fig.show()


    def graficar_evolution_matplotlib(self):
        sp500_data = yf.download(self.ticker, start=self.start_date, progress=False)
        
        # Crear el gráfico con matplotlib
        plt.figure(figsize=(8, 4))
        
        # Graficar los precios de cierre ajustados
        plt.plot(sp500_data.index, sp500_data['Adj Close'], lw=1.5, label='S&P 500')
        
        # Configurar el diseño del gráfico
        plt.title(f'Evolución de los precios del {self.value_name} desde {start_date}')
        plt.xlabel('Fecha')
        plt.ylabel('Precio de cierre ajustado')
        plt.legend()
        
        # Mostrar la cuadrícula
        plt.grid(True)
        
        # Mostrar el gráfico
        plt.show()

# Definir las fechas de las crisis financieras
crisis_dates = {
    'Crisis del petróleo de 1973': ('1973-01-01', '1974-01-01'),
    'Crisis financiera de América Latina (década de 1980)': ('1980-01-01', '1990-01-01'),
    'Lunes Negro (1987)': ('1987-10-01', '1987-11-01'),
    'Crisis financiera de Asia (1997-1998)': ('1997-07-01', '1998-01-01'),
    'Crisis del rublo ruso (1998)': ('1998-08-01', '1998-09-01'),
    'Crisis de las punto com (2000-2002)': ('2000-01-01', '2002-01-01'),
    'Crisis financiera mundial (2007-2008)': ('2007-01-01', '2009-01-01'),
    'Crisis de la deuda soberana en Europa (2010-2012)': ('2010-01-01', '2012-01-01'),
    'Crisis financiera en China (2015-2016)': ('2015-06-01', '2016-01-01'),
    'Crisis del COVID-19 (2020)': ('2020-01-01', '2021-01-01')
}

# %%
# Parámetros de análisis
ticker='^GSPC'
value_name = 'S&P 500'
start_date =  '1973-1-1'

# Crear una instancia de CrisisAnalyzer
analyzer = CrisisAnalyzer(ticker, value_name, start_date)

# Obtener la tabla de drawdowns
drawdown_df, mean_drawdown = analyzer.obtener_drawdown_df(crisis_dates)

# Graficar la evolución con matplotlib
analyzer.graficar_evolution_matplotlib()

# Graficar la evolución con plotly
#analyzer.graficar_evolution_plotly()

# Imprimir la media de los drawdowns
print(f"Media de drawdowns de las crisis: {round(mean_drawdown,2)}%")

# Exportar a Excel

# Set the desired export path (replace with your actual path)
export_path = "/home/enri/Descargas/Provisional/drawdown_SP500.xlsx"

# Export DataFrame to Excel file
drawdown_df.to_excel(export_path, index=False)  # Excluding index

# Mostrar la tabla
drawdown_df
# Out:
# Media de drawdowns de las crisis: 26.73%
#                                               Crisis Máximo Drawdown  \
# 0                        Crisis del petróleo de 1973          23.35%
# 1  Crisis financiera de América Latina (década de...          33.51%
# 2                                 Lunes Negro (1987)          31.47%
# 3              Crisis financiera de Asia (1997-1998)          10.80%
# 4                       Crisis del rublo ruso (1998)          13.95%
# 5                Crisis de las punto com (2000-2002)          36.77%
# 6              Crisis financiera mundial (2007-2008)          51.93%
# 7  Crisis de la deuda soberana en Europa (2010-2012)          19.39%
# 8             Crisis financiera en China (2015-2016)          12.25%
# 9                         Crisis del COVID-19 (2020)          33.92%
#
#   Fecha del Máximo Drawdown
# 0                1974-01-01
# 1                1990-01-01
# 2                1987-11-01
# 3                1998-01-01
# ...

# %% [markdown]
# <div style="background-color: #ffffcc; padding: 10px;">
#
# **<u>Análisis de Resultados</u>**
#
# - **Media de Drawdowns de las Crisis:**
#         La media de los drawdowns durante las crisis es del 26.73%. Esta cifra refleja el promedio de la pérdida máxima de valor del índice durante los periodos de crisis analizados.
#
# - **Crisis del Petróleo de 1973:**
#         Con un drawdown del 23.35%, esta crisis fue desencadenada por el embargo petrolero árabe, que llevó a un aumento significativo en los precios del petróleo y una consecuente recesión económica.
#
# - **Crisis Financiera de América Latina (década de 1980):**
#         La crisis financiera en América Latina resultó en un drawdown del 33.51%. Esta crisis fue causada por la incapacidad de varios países latinoamericanos para pagar sus deudas externas, afectando gravemente los mercados financieros globales.
#
# - **Lunes Negro (1987):**
#         El drawdown del 31.47% durante el Lunes Negro refleja el impacto de una caída repentina y dramática en los mercados bursátiles mundiales, incluida una caída del 22.6% en el Dow Jones en un solo día.
#
# - **Crisis Financiera de Asia (1997-1998):**
#         El drawdown del 10.80% durante la crisis financiera de Asia refleja el impacto relativamente menor en el S&P 500 en comparación con otras crisis, aunque fue significativa en los mercados asiáticos.
#
# - **Crisis del Rublo Ruso (1998):**
#         Con un drawdown del 13.95%, la crisis del rublo ruso fue causada por la devaluación del rublo y el default de la deuda rusa, afectando los mercados financieros globales.
#
# - **Crisis de las Punto Com (2000-2002):**
#         El drawdown del 36.77% refleja el impacto severo del estallido de la burbuja de las punto com, que llevó a una caída significativa en el valor de las empresas de tecnología.
#
# - **Crisis Financiera Mundial (2007-2008):**
#         Con un drawdown del 51.93%, esta crisis tuvo el mayor impacto en el S&P 500. Fue precipitada por el colapso de Lehman Brothers y la consecuente recesión global, afectando gravemente los mercados financieros en todo el mundo.
#
# - **Crisis de la Deuda Soberana en Europa (2010-2012):**
#         La crisis de la deuda soberana en Europa resultó en un drawdown del 19.39%. Esta crisis, centrada en la incapacidad de varios países europeos para gestionar sus deudas, generó una gran incertidumbre y afectó los mercados financieros globales.
#
# - **Crisis Financiera en China (2015-2016):**
#         El drawdown del 12.25% refleja el impacto global de las dificultades económicas en China, una de las principales economías emergentes del mundo.
#
# - **Crisis del COVID-19 (2020):**
#         La pandemia de COVID-19 provocó un drawdown del 33.92%. La naturaleza global y sin precedentes de esta crisis llevó a caídas drásticas en los mercados financieros debido a la incertidumbre y las restricciones económicas generalizadas.
#
# **Conclusión**
#
# El S&P 500 ha sido notablemente afectado por diversas crisis financieras a lo largo del tiempo, con un drawdown medio del 26.73%. Las crisis más severas, como la crisis financiera mundial de 2007-2008 y la crisis de las punto com, resultaron en drawdowns superiores al 30%, destacando la vulnerabilidad del índice a eventos económicos significativos.
#
# Los inversores en el S&P 500 deben ser conscientes de estos riesgos históricos y considerar estrategias de mitigación para proteger sus inversiones durante períodos de alta volatilidad. La diversificación y el monitoreo constante de los factores económicos globales y regionales pueden ayudar a reducir el impacto de futuras crisis en sus carteras de inversión.
#
# </div>

# %% [markdown]
# # Comportamiento del IBEX 35.

# %% [markdown]
# - **Crisis del petróleo de 1973:** Durante la crisis del petróleo de 1973, el IBEX 35 no estaba aún establecido, ya que comenzó a cotizar en 1992 como índice bursátil español.
#
# - **Crisis financiera de América Latina (década de 1980):** Durante la década de 1980, el IBEX 35 aún no existía como índice bursátil español.
#
# - ** Lunes Negro (1987):** En el lunes negro del 19 de octubre de 1987, el IBEX 35 no estaba aún establecido, ya que comenzó a cotizar en 1992.
#
# - **Crisis financiera de Asia (1997-1998):** Durante la crisis financiera de Asia, el IBEX 35 no experimentó mínimos notables asociados específicamente con esta crisis.
#
# - **Crisis del euro (1999-2002):** Durante la crisis del euro, el IBEX 35 experimentó una fuerte volatilidad y una caída significativa en su valor. En julio de 2012, alcanzó su mínimo, cayendo a alrededor de los 6,000 puntos.
#
# - **Crisis financiera mundial (2007-2008)** Durante la crisis financiera mundial, el IBEX 35 alcanzó su mínimo en julio de 2012, descendiendo a aproximadamente los 6,000 puntos.
#
# - **Crisis de la deuda soberana en Europa (2010-2012):** Durante la crisis de la deuda soberana en Europa, el IBEX 35 experimentó una fuerte volatilidad y alcanzó su mínimo en julio de 2012, cayendo a alrededor de los 6,000 puntos.
#
# - **Crisis bancaria en España (2012):** En 2012, España enfrentó una grave crisis bancaria debido a problemas en el sector inmobiliario y el alto nivel de deuda. Esta crisis llevó a la reestructuración y rescate de varios bancos españoles, y el IBEX 35 experimentó una fuerte caída, tocando fondo en julio de 2012 con niveles cercanos a los 6,000 puntos.
#
# - **Crisis financiera en China (2015-2016):** Durante la crisis financiera en China, el IBEX 35 experimentó volatilidad, pero no alcanzó mínimos notables asociados específicamente con esta crisis.
#
# - **Crisis bancaria en España (2018):** En 2018, el sector bancario español enfrentó desafíos significativos debido a la incertidumbre política en Italia, los riesgos asociados con el Brexit y la reestructuración de varios bancos europeos. Aunque no hubo un colapso específico del IBEX 35, el índice experimentó volatilidad y presión a la baja debido a la exposición significativa de los bancos españoles a los mercados internacionales.
#
# - **Crisis del COVID-19 (2020):** En marzo de 2020, debido a la crisis del COVID-19, el IBEX 35 alcanzó su mínimo, descendiendo a alrededor de los 6,000 puntos. La pandemia global causó una severa recesión económica y una caída masiva en los mercados bursátiles de todo el mundo, incluido el español. Las medidas de confinamiento, la interrupción de las cadenas de suministro y la caída en la demanda global afectaron significativamente a las empresas que componen el índice.

# %% [markdown]
# ## Valores mínimos durante las crisis.

# %%
import yfinance as yf

# Definir las fechas de las crisis financieras
crisis_dates = {
    'Crisis financiera de Asia (1997-1998)': ('1997-07-01', '1998-01-01'),
    'Crisis del rublo ruso (1998)': ('1998-08-01', '1998-09-01'),
    'Crisis de las punto com (2000-2002)': ('2000-01-01', '2002-01-01'),
    'Crisis financiera mundial (2007-2008)': ('2007-01-01', '2009-01-01'),
    'Crisis de la deuda soberana en Europa (2010-2012)': ('2010-01-01', '2012-01-01'),
    'Crisis bancaria en España (2012)': ('2012-1-4', '2012-09-30'),    
    'Crisis financiera en China (2015-2016)': ('2015-06-01', '2016-01-01'),
    'Crisis bancaria en España (2018)': ('2018-1-4', '2018-12-30'),    
    'Crisis del COVID-19 (2020)': ('2020-01-01', '2021-01-01')
}

# Función para obtener el valor mínimo del S&P 500 dentro de un rango de fechas
def obtener_minimo_sp500(start_date, end_date):
    data = yf.download('^IBEX', start=start_date, end=end_date, progress=False)
    return data['Adj Close'].min()

# Iterar sobre las crisis y obtener los valores mínimos
for crisis, (start_date, end_date) in crisis_dates.items():
    min_value = obtener_minimo_sp500(start_date, end_date)
    print(f"Valor mínimo del S&P 500 durante {crisis}: {min_value:.2f}")
# Out:
# Valor mínimo del S&P 500 durante Crisis financiera de Asia (1997-1998): 6049.89
# Valor mínimo del S&P 500 durante Crisis del rublo ruso (1998): 8264.69
# Valor mínimo del S&P 500 durante Crisis de las punto com (2000-2002): 6498.39
# Valor mínimo del S&P 500 durante Crisis financiera mundial (2007-2008): 7905.39
# Valor mínimo del S&P 500 durante Crisis de la deuda soberana en Europa (2010-2012): 7640.69
# Valor mínimo del S&P 500 durante Crisis bancaria en España (2012): 5956.29
# Valor mínimo del S&P 500 durante Crisis financiera en China (2015-2016): 9291.39
# Valor mínimo del S&P 500 durante Crisis bancaria en España (2018): 8363.90
# Valor mínimo del S&P 500 durante Crisis del COVID-19 (2020): 6107.20

# %% [markdown]
# ## Media y Mínimos drawdowns dutante las crisis.

# %%
# Definir las fechas de las crisis financieras
crisis_dates = {
    'Crisis financiera de Asia (1997-1998)': ('1997-07-01', '1998-01-01'),
    'Crisis del rublo ruso (1998)': ('1998-08-01', '1998-09-01'),
    'Crisis de las punto com (2000-2002)': ('2000-01-01', '2002-01-01'),
    'Crisis financiera mundial (2007-2008)': ('2007-01-01', '2009-01-01'),
    'Crisis de la deuda soberana en Europa (2010-2012)': ('2010-01-01', '2012-01-01'),
    'Crisis financiera en China (2015-2016)': ('2015-06-01', '2016-01-01'),
    'Crisis bancaria en España (2012)': ('2012-1-4', '2012-09-30'),       
    'Crisis bancaria en España (2018)': ('2018-1-4', '2020-04-30'),      
    'Crisis del COVID-19 (2020)': ('2020-01-01', '2021-01-01')
}

# Parámetros de análisis
ticker='^IBEX'
value_name = 'IBEX 35'
start_date =  '1993-7-12'

# Crear una instancia de CrisisAnalyzer
analyzer = CrisisAnalyzer(ticker, value_name, start_date)

# Obtener la tabla de drawdowns
drawdown_df, mean_drawdown = analyzer.obtener_drawdown_df(crisis_dates)

# Graficar la evolución con matplotlib
analyzer.graficar_evolution_matplotlib()

# Graficar la evolución con plotly
#analyzer.graficar_evolution_plotly()

# Imprimir la media de los drawdowns
print(f"Media de drawdowns de las crisis: {round(mean_drawdown,2)}%")

# Exportar a Excel

# Set the desired export path (replace with your actual path)
export_path = "/home/enri/Descargas/Provisional/drawdown_Ibex35.xlsx"

# Export DataFrame to Excel file
drawdown_df.to_excel(export_path, index=False)  # Excluding index

# Mostrar la tabla
drawdown_df
# Out:
# Media de drawdowns de las crisis: 34.5%
#                                               Crisis Máximo Drawdown  \
# 0              Crisis financiera de Asia (1997-1998)          17.49%
# 1                       Crisis del rublo ruso (1998)          21.25%
# 2                Crisis de las punto com (2000-2002)          49.30%
# 3              Crisis financiera mundial (2007-2008)          50.42%
# 4  Crisis de la deuda soberana en Europa (2010-2012)          37.49%
# 5             Crisis financiera en China (2015-2016)          19.60%
# 6                   Crisis bancaria en España (2012)          33.09%
# 7                   Crisis bancaria en España (2018)          42.44%
# 8                         Crisis del COVID-19 (2020)          39.43%
#
#   Fecha del Máximo Drawdown
# 0                1998-01-01
# 1                1998-09-01
# 2                2002-01-01
# 3                2009-01-01
# 4                2012-01-01
# 5                2016-01-01
# 6                2012-09-30
# ...

# %% [markdown]
# <div style="background-color: #ffffcc; padding: 10px;">
#
# **<u>Análisis de Resultados</u>**
# - **Media de Drawdowns de las Crisis:**
#         La media de los drawdowns durante las crisis es del 26.73%. Esta cifra refleja el promedio de la pérdida máxima de valor del índice durante los periodos de crisis analizados.
#
# - **Crisis financiera de Asia (1997-1998) y Crisis del rublo ruso (1998):**
#         Durante la crisis financiera de Asia, el IBEX 35 experimentó un drawdown del 17.49%, que aumentó a 21.25% con la crisis del rublo ruso. Estos eventos mostraron cómo crisis regionales pueden tener repercusiones globales, afectando incluso a los mercados europeos.
#
# - **Crisis de las punto com (2000-2002):**
#         El drawdown del 49.30% refleja la severidad del estallido de la burbuja tecnológica. Esta fue una de las crisis más significativas para el IBEX 35, destacando la vulnerabilidad de los mercados a las burbujas especulativas.
#
# - **Crisis financiera mundial (2007-2008):**
#         Con un drawdown del 50.42%, esta crisis tuvo el mayor impacto en el IBEX 35. El colapso de Lehman Brothers y la subsecuente recesión global causaron estragos en los mercados financieros a nivel mundial.
#
# - **Crisis de la deuda soberana en Europa (2010-2012):**
#         La crisis de la deuda soberana, especialmente severa en países como Grecia, España e Italia, resultó en un drawdown del 37.49%. Esto refleja la desconfianza en la capacidad de los países para gestionar sus deudas soberanas.
#
# - **Crisis bancaria en España (2012) y Crisis bancaria en España (2018):**
#         La crisis bancaria en España en 2012 y 2018 resultaron en drawdowns del 33.09% y 42.44% respectivamente. Estas cifras subrayan la fragilidad del sector bancario español durante esos períodos, con implicaciones significativas para el mercado de valores.
#
# - **Crisis financiera en China (2015-2016):**
#         La crisis en China, aunque más distante, provocó un drawdown del 19.60%. Esto demuestra la interconexión de los mercados globales y cómo problemas en una economía emergente pueden afectar a los mercados desarrollados.
#
# - **Crisis del COVID-19 (2020):**
#         La pandemia de COVID-19 resultó en un drawdown del 39.43%. Esta crisis sin precedentes afectó a todos los aspectos de la economía global, y el IBEX 35 no fue una excepción. La incertidumbre y las restricciones económicas causaron caídas significativas en los mercados.
#
# **Conclusión**
#
# El análisis de estos datos muestra cómo el IBEX 35 ha sido afectado por diversas crisis financieras a lo largo del tiempo. Las fluctuaciones reflejan la sensibilidad del índice a eventos tanto globales como regionales. Los inversores deben estar conscientes de estos riesgos y considerar estrategias de mitigación para proteger sus inversiones durante períodos de alta volatilidad.
#
# </div>

# %% [markdown]
# # Comportamiento del Eurostoxx 50.
# El Euro Stoxx 50 ESTX 50 PR.EUR (^STOXX50E), que es un índice bursátil de la zona euro, comenzó a cotizar el 26 de febrero de 1998. Fue creado por la empresa de indexación bursátil STOXX Ltd. y es uno de los índices más importantes de Europa, ya que representa a las 50 empresas líderes de la región en términos de capitalización bursátil y liquidez.

# %%
# ESTX 50 PR.EUR (^STOXX50E)
data = yf.download('^STOXX50E', progress=False)
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2007-03-30  4177.669922  4207.759766  4160.350098  4181.029785  4181.029785
# 2007-04-02  4177.310059  4191.759766  4163.770020  4189.549805  4189.549805
# 2007-04-03  4199.540039  4248.069824  4199.540039  4246.299805  4246.299805
# 2007-04-04  4252.709961  4261.830078  4242.049805  4261.830078  4261.830078
# 2007-04-05  4259.979980  4274.169922  4253.790039  4271.540039  4271.540039
# ...                 ...          ...          ...          ...          ...
# 2024-06-25  4938.439941  4938.439941  4910.919922  4935.970215  4935.970215
# 2024-06-26  4954.790039  4975.810059  4889.229980  4915.939941  4915.939941
# 2024-06-27  4918.629883  4935.109863  4897.180176  4902.600098  4902.600098
# 2024-06-28  4909.299805  4922.839844  4880.979980  4894.020020  4894.020020
# 2024-07-01  4924.080078  4981.310059  4923.319824  4938.259766  4938.259766
#
#               Volume
# Date
# ...

# %% [markdown]
# ## Cotizaciónes minimas en las crisis.

# %% [markdown]
# - **Crisis del petróleo de 1973:** Durante la crisis del petróleo de 1973, el Euro Stoxx 50 no estaba aún establecido, ya que comenzó a cotizar en 1998 como índice bursátil europeo.
#
# - **Crisis financiera de América Latina (década de 1980):** Durante la década de 1980, el Euro Stoxx 50 no estaba aún establecido.
#
# - **Lunes Negro (1987):** En el lunes negro del 19 de octubre de 1987, el Euro Stoxx 50 no estaba aún establecido.
#
# - **Crisis financiera de Asia (1997-1998):** Durante la crisis financiera de Asia, el Euro Stoxx 50 no experimentó mínimos notables asociados específicamente con esta crisis.
#
# - **Crisis del euro (1999-2002):** Durante la crisis del euro, el Euro Stoxx 50 alcanzó su mínimo en septiembre de 2002, cayendo a alrededor de los 2,200 puntos.
#
# - **Crisis financiera mundial (2007-2008):** Durante la crisis financiera mundial, el Euro Stoxx 50 alcanzó su mínimo en marzo de 2009, descendiendo a aproximadamente los 1,800 puntos.
#
# - **Crisis de la deuda soberana en Europa (2010-2012):** Durante la crisis de la deuda soberana en Europa, el Euro Stoxx 50 alcanzó su mínimo en julio de 2012, cayendo a alrededor de los 2,200 puntos.
#
# - **Crisis financiera en China (2015-2016):** Durante la crisis financiera en China, el Euro Stoxx 50 experimentó volatilidad, pero no alcanzó mínimos notables asociados específicamente con esta crisis.
#
# - **Crisis del COVID-19 (2020):** En marzo de 2020, debido a la crisis del COVID-19, el Euro Stoxx 50 alcanzó su mínimo, descendiendo a alrededor de los 2,500 puntos.

# %%
import yfinance as yf

# Definir las fechas de las crisis financieras
crisis_dates = {
    'Crisis financiera mundial (2007-2008)': ('2007-01-01', '2009-01-01'),
    'Crisis de la deuda soberana en Europa (2010-2012)': ('2010-01-01', '2012-01-01'),
    'Crisis financiera en China (2015-2016)': ('2015-06-01', '2016-01-01'),
    'Crisis del COVID-19 (2020)': ('2020-01-01', '2021-01-01')
}

# Función para obtener el valor mínimo del S&P 500 dentro de un rango de fechas
def obtener_minimo_eurostoxx50(start_date, end_date):
    data = yf.download('^STOXX50E', start=start_date, end=end_date, progress=False)
    return data['Adj Close'].min()

# Iterar sobre las crisis y obtener los valores mínimos
for crisis, (start_date, end_date) in crisis_dates.items():
    min_value = obtener_minimo_eurostoxx50(start_date, end_date)
    print(f"Valor mínimo del Eurostoxx 50 durante {crisis}: {min_value:.2f}")
# Out:
# Valor mínimo del Eurostoxx 50 durante Crisis financiera mundial (2007-2008): 2165.91
# Valor mínimo del Eurostoxx 50 durante Crisis de la deuda soberana en Europa (2010-2012): 1995.01
# Valor mínimo del Eurostoxx 50 durante Crisis financiera en China (2015-2016): 3019.34
# Valor mínimo del Eurostoxx 50 durante Crisis del COVID-19 (2020): 2385.82

# %% [markdown]
# ## Media y Mínimos drawdowns durante las crisis.

# %%
# Definir las fechas de las crisis financieras
crisis_dates = {
    'Crisis financiera mundial (2007-2008)': ('2007-01-01', '2009-01-01'),
    'Crisis de la deuda soberana en Europa (2010-2012)': ('2010-01-01', '2012-01-01'),
    'Crisis financiera en China (2015-2016)': ('2015-06-01', '2016-01-01'),
    'Crisis del COVID-19 (2020)': ('2020-01-01', '2021-01-01')
}

# Parámetros de análisis
ticker='^STOXX50E'
value_name = 'Euro Stoxx 50'
start_date = '2007-03-30'  # Fecha de inicio para el análisis

# Crear una instancia de CrisisAnalyzer
analyzer = CrisisAnalyzer(ticker, value_name, start_date)

# Obtener la tabla de drawdowns
drawdown_df, mean_drawdown = analyzer.obtener_drawdown_df(crisis_dates)

# Graficar la evolución con matplotlib
analyzer.graficar_evolution_matplotlib()

# Graficar la evolución con plotly
#analyzer.graficar_evolution_plotly()

# Imprimir la media de los drawdowns
print(f"Media de drawdowns de las crisis: {round(mean_drawdown,2)}%")

# Exportar a Excel
# Set the desired export path (replace with your actual path)
export_path = "/home/enri/Descargas/Provisional/drawdown_eurostoxx50.xlsx"

# Export DataFrame to Excel file
drawdown_df.to_excel(export_path, index=False)  # Excluding indexEurostoxx50.xlsx"

# Export DataFrame to Excel file
drawdown_df.to_excel(export_path, index=False)  # Excluding index

# Mostrar la tabla
drawdown_df
# Out:
# Media de drawdowns de las crisis: 35.96%
#                                               Crisis Máximo Drawdown  \
# 0              Crisis financiera mundial (2007-2008)          52.48%
# 1  Crisis de la deuda soberana en Europa (2010-2012)          34.97%
# 2             Crisis financiera en China (2015-2016)          18.10%
# 3                         Crisis del COVID-19 (2020)          38.27%
#
#   Fecha del Máximo Drawdown
# 0                2009-01-01
# 1                2012-01-01
# 2                2016-01-01
# 3                2021-01-01

# %% [markdown]
# <div style="background-color: #ffffcc; padding: 10px;">
#
# **<u>Análisis de Resultados</u>**
#
# - **Media de Drawdowns de las Crisis:**
#         La media de los drawdowns durante las crisis es del 26.73%. Esta cifra refleja el promedio de la pérdida máxima de valor del índice durante los periodos de crisis analizados.
#
# - **Crisis Financiera Mundial (2007-2008):**
#         Con un drawdown del 52.48%, esta crisis tuvo el mayor impacto en el Eurostoxx 50. La crisis financiera mundial fue precipitada por el colapso de Lehman Brothers y la consecuente recesión global, afectando gravemente los mercados financieros en todo el mundo, incluido el Eurostoxx 50.
#
# - **Crisis de la Deuda Soberana en Europa (2010-2012):**
#         La crisis de la deuda soberana en Europa resultó en un drawdown del 34.97%. Esta crisis, centrada en la incapacidad de varios países europeos para gestionar sus deudas, generó una gran incertidumbre y una significativa caída en el valor del Eurostoxx 50.
#
# - **Crisis Financiera en China (2015-2016):**
#         El drawdown del 18.10% durante la crisis financiera en China refleja el impacto global de las dificultades económicas en una de las principales economías emergentes del mundo. Aunque el impacto fue menor en comparación con otras crisis, sigue siendo significativo.
#
# - **Crisis del COVID-19 (2020):**
#         La pandemia de COVID-19 provocó un drawdown del 38.27%. La naturaleza global y sin precedentes de esta crisis llevó a caídas drásticas en los mercados financieros, incluyendo el Eurostoxx 50, debido a la incertidumbre y las restricciones económicas generalizadas.
#
# **Conclusión**
#
# El Eurostoxx 50 ha sido notablemente afectado por diversas crisis financieras a lo largo del tiempo, con un drawdown medio del 26.73%. Las crisis más severas, como la crisis financiera mundial de 2007-2008 y la crisis del COVID-19, resultaron en drawdowns superiores al 30%, destacando la vulnerabilidad del índice a eventos económicos significativos. Las crisis de la deuda soberana en Europa y la crisis financiera en China también demostraron cómo problemas regionales pueden tener repercusiones globales, afectando al Eurostoxx 50.
#
# Los inversores en el Eurostoxx 50 deben ser conscientes de estos riesgos históricos y considerar estrategias de mitigación para proteger sus inversiones durante períodos de alta volatilidad. La diversificación y el monitoreo constante de los factores económicos globales y regionales pueden ayudar a reducir el impacto de futuras crisis en sus carteras de inversión.
#
# </div>

# %% [markdown]
# # Comparación de la evolución de los tres índices.

# %%
# Datos normalizados

import yfinance as yf
import matplotlib.pyplot as plt

# Definir los tickers de los índices
tickers = {
    'S&P 500': '^GSPC',
    'Euro Stoxx 50': '^STOXX50E',
    'IBEX 35': '^IBEX'
}

# Descargar datos históricos
data = {}
for name, ticker in tickers.items():
    data[name] = yf.download(ticker, start='2000-01-01', end='2024-12-31', progress=False)['Close']

# Normalizar los datos para que todos comiencen en el mismo punto
normalized_data = {}
for name, prices in data.items():
    normalized_data[name] = prices / prices.iloc[0] * 100

# Crear la gráfica
plt.figure(figsize=(8, 4))
for name, prices in normalized_data.items():
    plt.plot(prices, lw=1.5, label=name)

# Añadir título y etiquetas
plt.title('Evolución de las Cotizaciones de los Índices (Normalizados)')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre Normalizado')
plt.legend()
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# <div style="background-color: #ffffcc; padding: 10px;">
#
# **<u>Análisis de Resultados</u>**
#
# - **S&P 500 (Línea azul):**
#         Muestra un crecimiento significativo a lo largo del periodo, especialmente después de la crisis financiera de 2008.
#         A pesar de las caídas notables durante la crisis de 2008 y la pandemia de COVID-19 en 2020, el S&P 500 se ha recuperado y ha alcanzado nuevos máximos históricos, lo que refleja un rendimiento positivo sostenido en el largo plazo.
#
# - **Euro Stoxx 50 (Línea naranja):**
#         La evolución del Euro Stoxx 50 es más modesta en comparación con el S&P 500.
#         Después de la crisis financiera de 2008 y la crisis de la deuda soberana en Europa, el índice ha tenido dificultades para alcanzar los máximos anteriores. Aunque ha habido alguna recuperación, el crecimiento no ha sido tan pronunciado como en el S&P 500.
#
# - **IBEX 35 (Línea verde):**
#         Similar al Euro Stoxx 50, el IBEX 35 también muestra un crecimiento más moderado.
#         Experimenta fuertes caídas durante las crisis financieras y tiene una recuperación más lenta. Después de la crisis de 2008 y la crisis de la deuda soberana en Europa, el índice muestra volatilidad y no ha logrado alcanzar los niveles anteriores a la crisis.
#
# **<u>Observaciones Clave</u>**
#
# **Comparación de Crecimiento:**
#         El S&P 500 ha superado ampliamente a los otros dos índices, lo que indica un mayor crecimiento en el mercado estadounidense en comparación con los mercados europeos.
#         Tanto el Euro Stoxx 50 como el IBEX 35 han mostrado un rendimiento relativamente plano, destacando los desafíos económicos y financieros en Europa durante las últimas dos décadas.
#
# **<u>Impacto de las Crisis Financieras:</u>**
#         Todos los índices muestran caídas significativas durante la crisis financiera de 2008, lo que resalta el impacto global de este evento.
#         La crisis de la deuda soberana en Europa afectó notablemente al Euro Stoxx 50 y al IBEX 35, mientras que el S&P 500, aunque afectado, se recuperó más rápidamente.
#
# **<u>Volatilidad:</u>**
#         El IBEX 35 muestra una mayor volatilidad en comparación con el S&P 500 y el Euro Stoxx 50, reflejando quizás una mayor sensibilidad a los eventos económicos y políticos en España.
#
# Esta gráfica proporciona una visión clara de cómo los diferentes mercados han evolucionado a lo largo del tiempo y cómo han reaccionado a diversas crisis financieras. El fuerte desempeño del S&P 500 frente a los índices europeos destaca la importancia de diversificar las inversiones geográficamente.
#
#
# </div>

# %% [markdown]
# # Nota de advertencias.
# Este notebook tiene fines educativos y de demostración solamente. Las estrategias de inversión presentadas aquí son ejemplos y pueden contener errores. Se recomienda encarecidamente que cualquier decisión de inversión se tome después de consultar con un asesor financiero calificado. No se proporciona asesoramiento financiero, y cualquier uso de la información presentada es bajo su propio riesgo. Agradecemos cualquier retroalimentación para mejorar la calidad de estos ejemplos.
# Es importante recordar que no hay una estrategia única que funcione en todos los casos, y siempre hay un riesgo asociado con la inversión. Es recomendable realizar pruebas exhaustivas y análisis antes de implementar cualquier estrategia en un entorno de trading real.
